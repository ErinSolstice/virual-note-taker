# %%
import cv2
import glob

imgs = glob.glob(f"bel_train/*.jpg")
imgSizes = []

for imgPath in imgs:
    im = cv2.imread(imgPath)
    imgSizes.append(im.shape)

# %%
print(imgSizes)
print(list(map(max, zip(*imgSizes))))
print(list(map(min, zip(*imgSizes))))
# Out:
# [(64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64, 200, 3), (64
# ...
